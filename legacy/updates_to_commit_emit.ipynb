# %%
# This function multiplies a locally held prior by a locally modified country weights file, this preceeded Tom's analysis
# def update_commit_emit():
#     import pandas as pd 
#     import numpy as np
    
#     # import the country/sector/year tong data, and use the weights file to modify it
#     country_data = pd.read_csv('~/Desktop/Founders_Pledge/affectable_emissions_active_repo/Affectable-Emissions/data_files/tong_commited_emit_data_weighted/country_level_posteriors/all_countriesxprior.csv', index_col = 0)
#     weights = pd.read_csv('~/Desktop/Founders_Pledge/affectable_emissions_active_repo/Affectable-Emissions/data_files/tong_commited_emit_data_weighted/country_level_posteriors/all_countries_weightsMODIFIED.csv', index_col = 0)
    
#     posterior = weights.iloc[:,1:8] * country_data.iloc[:,1:8]
#     posterior[['Year', 'country']] = weights[['Year', 'country']]

#     posterior.to_csv('~/Desktop/Founders_Pledge/affectable_emissions_active_repo/Affectable-Emissions/data_files/tong_commited_emit_data_weighted/posteriors.csv')
#     #print(posterior)
# update_commit_emit()
